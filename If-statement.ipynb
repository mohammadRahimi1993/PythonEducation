# %% [markdown]
# # Conditional expressions

# %% [markdown]
# ![Condition.JPG](attachment:Condition.JPG)

# %% [markdown]
# # If

# %% [markdown]
# if condition:
#     statement 1:
#     statement 2:
#     statement 3:

# %%
number = 4
if number > 5:
    print(number*20)
print("Next line")
# Out:
# Next line

# %% [markdown]
# if condition:
#     statement 1
# else:
#     statement 2

# %%
x=10
y=20
if(x > y):
    print(x)
else:
    print(y)
print("Next lint")
# Out:
# 20
# Next lint

# %% [markdown]
# ### Example

# %%
# username = User
# Pass = 123456

# %% [raw]
# if condition-1:
#     statement 1
# elif condition-2:
#     statement 2
# elif condition 3:
#     statement 3
#     ...
# else:
#     statement n

# %%
user = input("Enter user type: ")
if user == "admin":
    print("your welcom admin")
elif user == "user":
    print("your welcome user")
elif user == "Guest":
    print("your welcom guest")
else:
    print("you don't member of site")
# Out:
# Enter user type: dkslkfj
# you don't member of site
