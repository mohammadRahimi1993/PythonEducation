# %% [markdown]
# # Print command

# %%
print("Mohammad Rahimi")
print('Mohammad Rahimi')
print('A')
print("A")
# Out:
# Mohammad Rahimi
# Mohammad Rahimi
# A
# A

# %% [markdown]
# # DataType

# %% [markdown]
# ![DataType.JPG](attachment:DataType.JPG)

# %%
# Integer
integer_number = 2
float_number = 2.1
complex_number = 1 + 3j

# String
first_name = "Mohammad"
last_name = 'Rahimi'

# special String
sentence_1 = 'I\'m student'
sentence_2 = "I'm student"
character = "A"

# Boolean
bool_variable= True
bool_variable= False

# List
list_numbers = [1,2,3,4]
tuple_numbers = (1,2,3,4)
dictionary = { "first_name":"Mohammad",
               "last_name":"Rahimi"}
set_numbers = {1,2,3,4}

# %%
name = "محمد"
print(name)
# Out:
# محمد

# %%
print(dictionary)
for key in dictionary.keys():
    print(key)
    print(dictionary[key])
# Out:
# {'first_name': 'Mohammad', 'last_name': 'Rahimi'}
# first_name
# Mohammad
# last_name
# Rahimi

# %% [markdown]
# # Type command

# %% [raw]
# Csharp is static programming
# int number = 2
# str name = "Mohammad"

# %%
# Python is dynamic programming
number = 2
name = "mohammad"

# %%
print(type(name))
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>
