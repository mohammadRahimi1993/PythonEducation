# %% [markdown]
# # List

# %% [markdown]
# ![List.JPG](attachment:List.JPG)

# %%
my_list = [20 , 20 , 30, 30, "Ali", (12,14,1+2j)]
print(my_list)
print(my_list[0])
for item in my_list:
    print(item, end =" ")
print()
print("Lenght of list is: ", len(my_list))
print(type(my_list))
# Out:
# [20, 20, 30, 30, 'Ali', (12, 14, (1+2j))]
# 20
# 20 20 30 30 Ali (12, 14, (1+2j))
# Lenght of list is:  6
# <class 'list'>

# %%
my_list = [1,2,3]
# Constructor
numbers = list((1,2,"hassan",1+2j))
print(numbers)
# Out:
# [1, 2, 'hassan', (1+2j)]

# %%
print(numbers[1])
print(numbers[-1])
print(numbers[1:5])
print(numbers[:3])
print(numbers[2:])
print(numbers[-3:-1])
if "hassan" in numbers:
    print("hassan is exist: ")
else:
    print("hassna don't exit")
# Out:
# 2
# (1+2j)
# [2, 'hassan', (1+2j)]
# [1, 2, 'hassan']
# ['hassan', (1+2j)]
# [2, 'hassan']
# hassan is exist:

# %%
print(numbers)
numbers[1] = 10
print(numbers)


names = ["Ali","Zahra","Hassan"]
print(names)
names[1:3] = ["Fatemeh","Hossein"]
print(names)

names.insert(1,"sajad")
print(names)
names.append("saeid")
print(names)
# Out:
# [1, 10, 'hassan', (1+2j)]
# [1, 10, 'hassan', (1+2j)]
# ['Ali', 'Zahra', 'Hassan']
# ['Ali', 'Fatemeh', 'Hossein']
# ['Ali', 'sajad', 'Fatemeh', 'Hossein']
# ['Ali', 'sajad', 'Fatemeh', 'Hossein', 'saeid']

# %%
names.remove("saeid")
print(names)
name = names.pop(2)
print(names)
print(name)
name = names.pop()
print(name)
# Out:
# ['Ali', 'sajad', 'Fatemeh', 'Hossein']
# ['Ali', 'sajad', 'Hossein']
# Fatemeh
# Hossein

# %%
print(names)
del names[0]
print(names)
names.clear()
print(names)
# Out:
# ['Ali', 'sajad']
# ['sajad']
# []

# %% [markdown]
# # Tuple

# %% [markdown]
# ![Tuple.JPG](attachment:Tuple.JPG)

# %% [markdown]
# # Set

# %% [markdown]
# ![Set.JPG](attachment:Set.JPG)

# %% [markdown]
# # Dictionary

# %% [markdown]
# ![Dictionary.JPG](attachment:Dictionary.JPG)
